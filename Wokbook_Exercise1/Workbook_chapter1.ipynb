# %% [markdown]
# CHAPTER 1

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %% [markdown]
# EXERCISES

# %% [markdown]
# Exercise 1

# %%
Print('Hello world!')

# %%
print('Hello world!') # In Python, the function for printing is called "print" with a
#Python is sensitive to the capitalization of function names, so using "Print" with an uppercase "P" causes an error because Python doesn't recognize it as the correct function.
# Out:
# Hello world!

# %%
print'Hello world!')

# %%
print('Hello world!')#The error occurs because the print statement is missing opening parentheses.
#print is a function and requires parentheses around its arguments.
# Out:
# Hello world!

# %%
print('Hello world!'')

# %%
print('Hello world!') #The error was caused by using both single and double quotes to enclose the string 'Hello world!', which is not allowed in Python, so removing the extra single quotes to fixed the issue.
# Out:
# Hello world!

# %% [markdown]
# Exercise 2
#
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x) #44 is the answer
# Out:
# 44

# %% [markdown]
# Exercise 3
#
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1
print(X)

# %%
x = 43
x = x + 1
print(x)  # The variable 'x' is defined with a lowercase 'x', so it should be printed with a lowercase 'x'. Python is case-sensitive, so 'X' and 'x' are treated as different variables.
#so i change the variable 'X' to 'x' to fix the error
# Out:
# 44
