# %% [markdown]
# CHAPTER 4

# %% [markdown]
# EXERCISES

# %% [markdown]
# Rewrite your pay computation with time-and-a-half for overtime and create a function called compute pay which takes two parameters (hours and rate).

# %% [markdown]
# Enter Hours: 45
#
# Enter Rate: 10
#
# Pay: 475.0

# %%
def compute_pay(hours, rate):
    if hours <= 40:
        pay = hours * rate
    else:
        regular_pay = 40 * rate
        overtime_pay = (hours - 40) * rate * 1.5
        pay = regular_pay + overtime_pay
    return pay

hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = compute_pay(hours, rate)
print("Pay:", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Write a function called computegrade that takes a score as its parameter and returns a grade as a string using the following table:

# %%
Score           Grade
[ 97, 100]      1.0
[ 93,  97)        1.25
[ 89,  93)        1.5
[ 85,  89)        1.75
[ 81,  85)        2.0
[ 77,  81)        2.25
[ 74,  77)        2.5
[ 0,   74)        3.0

Run the program repeatedly to test the various different values for input.

# %%
def compute_grade(score):
    if 97 <= score <= 100:
        grade = "1.0"
    elif 93 <= score < 97:
        grade = "1.25"
    elif 89 <= score < 93:
        grade = "1.5"
    elif 85 <= score < 89:
        grade = "1.75"
    elif 81 <= score < 85:
        grade = "2.0"
    elif 77 <= score < 81:
        grade = "2.25"
    elif 74 <= score < 77:
        grade = "2.5"
    else:
        grade = "3.0"
    return grade

#Testing the function with various inputs
scores = [100, 95, 90, 87, 83, 79, 76, 70]

for score in scores:
    print("Score:", score, "Grade:", compute_grade(score))
# Out:
# Score: 100 Grade: 1.0
# Score: 95 Grade: 1.25
# Score: 90 Grade: 1.5
# Score: 87 Grade: 1.75
# Score: 83 Grade: 2.0
# Score: 79 Grade: 2.25
# Score: 76 Grade: 2.5
# Score: 70 Grade: 3.0
