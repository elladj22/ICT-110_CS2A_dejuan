# %% [markdown]
# CHAPTER 6

# %% [markdown]
# EXERCISES

# %% [markdown]
# Exercise 1

# %% [markdown]
# Given the code below
#
# text = 'Business Analytics'
#
#
# What will the following expressions produce?
#
# text[4]
#
# text[2:4]
#
# text[:4]
#
# text[4:]
#
# text[-2]
#
# text[-4:-2]
#
# text[-2:]
#
# text[:-2]

# %%
text = 'Business Analytics'

print(text[4])       # Output: 'n' (the character at index 4)

print(text[2:4])     # Output: 'si' (characters from index 2 up to, but not including, index 4)

print(text[:4])      # Output: 'Busi' (characters from the start up to, but not including, index 4)

print(text[4:])      # Output: 'ness Analytics' (characters from index 4 to the end)

print(text[-2])      # Output: 'c' (the second-to-last character)

print(text[-4:-2])   # Output: 'ti' (characters from the fourth-to-last up to, but not including, the second-to-last)

print(text[-2:])     # Output: 'cs' (characters from the second-to-last to the end)

print(text[:-2])     # Output: 'Business Analyti' (characters from the start up to, but not including, the second-to-last)
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# Exercise 2

# %% [markdown]
# Given the code below:
#
# phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
# 'One '
#
# 'Ring'
#
# 'all'
#
# 'them'
#
# 'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

print(phrase[0:4])      # 'One '
print(phrase[4:8])      # 'Ring'
print(phrase[-3:])      # 'all'
print(phrase[17:21])    # 'them'
print(phrase)           # 'One Ring to rule them all'

#string indexing starts from 0. Positive indices count from the beginning of the string,
# Negative indices count from the end.
# phrase[0:4] gives the substring from index 0 up to, but not including, index 4, which is 'One '.
# phrase[4:8] gives 'Ring', and so on.
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a full name, then does the following:
#
# strips the name of any trailing spaces
#
# capitalizes the first letter
#
# puts the rest into smaller letters

# %%
for i in range(10) :
  name = input("Enter your full name: ")
  if name == "exit" :
      break
  print(name.strip().capitalize())
# Out:
# Enter your full name: ella florenz
# Ella florenz
# Enter your full name: Millen
# Millen
# Enter your full name: zarr
# Zarr
# Enter your full name: exit
