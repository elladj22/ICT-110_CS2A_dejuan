# %% [markdown]
# CHAPTER 7

# %% [markdown]
# EXERCISES

# %% [markdown]
# Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.

# %%
file_name = input("Enter the name of the file: ")

try:
    with open(file_name, 'r') as file:
        for line in file:
            print(line.upper(), end='')
except FileNotFoundError:
    print("File not found.")
# Out:
# Enter the name of the file: /content/drive/MyDrive/WorkBook2_Exercises/blame.txt
# HELLO WORLD!

# %% [markdown]
# Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.

# %%
file_name = input("Enter the name of the file: ")

try:
    with open(file_name, 'r') as file:
        line_count = sum(1 for line in file)
    print("Number of lines in the file:", line_count)
except FileNotFoundError:
    print("File not found.")
# Out:
# Enter the name of the file: /content/drive/MyDrive/WorkBook2_Exercises/blame.txt
# Number of lines in the file: 1

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %%
fileName = input("Enter the file name: ")
total = 0.0
count = 0
try :
    basa = open(fileName, 'r')
    for line in basa :
        if line.startswith("X-DSPAM-Confidence:"):
                confidence = float(line.split(":")[1].strip())
                total += confidence
                count += 1
    if count > 0:
        average = total / count
        print("Average spam confidence:",average)
    else:
        print("No lines with spam confidence found.")
    basa.close();
except FileNotFoundError:
    print(f"File '{fileName}' not found.")
# Out:
# Enter the file name: /content/drive/MyDrive/WorkBook2_Exercises/blame.txt
# No lines with spam confidence found.
